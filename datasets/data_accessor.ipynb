# %%
# import packages

import zenodo_get
import os

# %%
# retrieve files from Zenodo:
# aib9.out.zip: zipped file containing raw output of the Aib9 OpenMM MD simulation
# aib9_openmm.zip: zipped folder containing all input files for the Aib9 OpenMM MD simulation, as well as the generated trajectory
# data_input.zip: zipped folder containing input datasets for the GMM and Aib9 numerical experiments
# data_output.zip: zipped folder containing output data and experimental results for three generative models (NS, CFM, DDPM) on the input datasets, 
# included for posterity (file names do not synchronize with most recent repository naming conventions)

! zenodo_get 14679134
# Out:
# Title: Model Comparison Benchmark Datasets, Results, and Peptide MD Trajectory
# Keywords:
# Publication date: 2024-11-13
# DOI: 10.5281/zenodo.14679134
# Total size: 3.6 GB
#
# Link: https://zenodo.org/records/14679134/files/data_input.zip   size: 446.3 MB
# 100% [..................................................] 446331086 / 446331086
# Checksum is correct. (6873c25f32a5d66ca15f4e7b2ff8db51)
#
# Link: https://zenodo.org/records/14679134/files/aib9.out.zip   size: 715.4 kB
# 100% [........................................................] 715379 / 715379
# Checksum is correct. (403e5394d950ad76ecc7059fa6535453)
#
# Link: https://zenodo.org/records/14679134/files/aib9_openmm.zip   size: 1.3 GB
# 100% [................................................] 1251938228 / 1251938228
# Checksum is correct. (19d8ed738407e5a320894e514b584604)
#
# Link: https://zenodo.org/records/14679134/files/data_output.zip   size: 1.9 GB
# ...

# %%
# unzip files

! unzip -o data_input.zip
! unzip -o data_output.zip
! unzip -o aib9_openmm.zip
! unzip -o aib9.out.zip
# Out:
# Archive:  data_input.zip
#    creating: data_input/
#   inflating: data_input/gmm_dim_20_modes_4.npy
#    creating: data_input/.ipynb_checkpoints/
#   inflating: data_input/gmm_dim_40_modes_4.npy
#   inflating: data_input/gmm_dim_50_modes_2_asym_0.25.npy
#   inflating: data_input/gmm_dim_50_modes_2_asym_0.001.npy
#   inflating: data_input/gmm_dim_50_modes_4.npy
#   inflating: data_input/gmm_dim_50_modes_2_asym_0.1.npy
#   inflating: data_input/gmm_dim_10_modes_4.npy
#   inflating: data_input/gmm_dim_80_modes_50.npy
#   inflating: data_input/gmm_dim_50_modes_2_asym_0.05.npy
#   inflating: data_input/gmm_dim_50_modes_2_asym_0.5.npy
#   inflating: data_input/gmm_dim_80_modes_35.npy
#   inflating: data_input/gmm_dim_80_modes_5.npy
#   inflating: data_input/gmm_dim_80_modes_30.npy
#   inflating: data_input/gmm_dim_30_modes_4.npy
#   inflating: data_input/gmm_dim_50_modes_2_asym_0.01.npy
#   inflating: data_input/gmm_dim_60_modes_4.npy
#   inflating: data_input/gmm_dim_80_modes_10.npy
# ...

# %%
# delete extraneous zip files

! rm data_input.zip
! rm data_output.zip
! rm aib9.out.zip
! rm aib9_openmm.zip
! rm md5sums.txt
